# %%
from tabula import read_pdf
from tabulate import tabulate
import camelot.io as camelot
import os
import pandas as pd
import numpy as np
import PyPDF2

# %%
# Finding all file names in a folder 2021
file_names = []
for i in os.listdir('2021'):
    # print(i)
    if(i!='failed colleges'):
        file_names.append(i)
file_names
# Out:
# ['IR-O-C-16604.pdf',
#  'IR-O-C-37013.pdf',
#  'IR-O-I-1074.pdf',
#  'IR-O-I-1075.pdf',
#  'IR-O-I-1110.pdf',
#  'IR-O-I-1357.pdf',
#  'IR-O-I-1441.pdf',
#  'IR-O-I-1480.pdf',
#  'IR-O-I-1486.pdf',
#  'IR-O-N-10.pdf',
#  'IR-O-U-0006.pdf',
#  'IR-O-U-0013.pdf',
#  'IR-O-U-0020.pdf',
#  'IR-O-U-0025.pdf',
#  'IR-O-U-0027.pdf',
#  'IR-O-U-0037.pdf',
#  'IR-O-U-0042.pdf',
#  'IR-O-U-0052.pdf',
#  'IR-O-U-0053.pdf',
#  'IR-O-U-0055.pdf',
#  'IR-O-U-0056.pdf',
#  'IR-O-U-0064.pdf',
#  'IR-O-U-0078.pdf',
#  'IR-O-U-0098.pdf',
#  'IR-O-U-0099.pdf',
#  'IR-O-U-0107.pdf',
#  'IR-O-U-0108.pdf',
#  'IR-O-U-0109.pdf',
#  'IR-O-U-0120.pdf',
#  'IR-O-U-0136.pdf',
#  'IR-O-U-0139.pdf',
#  'IR-O-U-0149.pdf',
#  'IR-O-U-0184.pdf',
#  'IR-O-U-0196.pdf',
#  'IR-O-U-0205.pdf',
#  'IR-O-U-0220.pdf',
#  'IR-O-U-0222.pdf',
#  'IR-O-U-0234.pdf',
#  'IR-O-U-0235.pdf',
#  'IR-O-U-0237.pdf',
#  'IR-O-U-0251.pdf',
#  'IR-O-U-0253.pdf',
#  'IR-O-U-0260.pdf',
#  'IR-O-U-0262.pdf',
#  'IR-O-U-0272.pdf',
#  'IR-O-U-0273.pdf',
#  'IR-O-U-0295.pdf',
#  'IR-O-U-0304.pdf',
#  'IR-O-U-0305.pdf',
#  'IR-O-U-0306.pdf',
#  'IR-O-U-0308.pdf',
#  'IR-O-U-0318.pdf',
#  'IR-O-U-0323.pdf',
#  'IR-O-U-0329.pdf',
#  'IR-O-U-0331.pdf',
#  'IR-O-U-0334.pdf',
#  'IR-O-U-0341.pdf',
#  'IR-O-U-0355.pdf',
#  'IR-O-U-0356.pdf',
#  'IR-O-U-0357.pdf',
#  'IR-O-U-0363.pdf',
#  'IR-O-U-0369.pdf',
#  'IR-O-U-0374.pdf',
#  'IR-O-U-0376.pdf',
#  'IR-O-U-0377.pdf',
#  'IR-O-U-0378.pdf',
#  'IR-O-U-0379.pdf',
#  'IR-O-U-0389.pdf',
#  'IR-O-U-0391.pdf',
#  'IR-O-U-0410.pdf',
#  'IR-O-U-0435.pdf',
#  'IR-O-U-0436.pdf',
#  'IR-O-U-0439.pdf',
#  'IR-O-U-0446.pdf',
#  'IR-O-U-0447.pdf',
#  'IR-O-U-0448.pdf',
#  'IR-O-U-0456.pdf',
#  'IR-O-U-0458.pdf',
#  'IR-O-U-0463.pdf',
#  'IR-O-U-0467.pdf',
#  'IR-O-U-0473.pdf',
#  'IR-O-U-0474.pdf',
#  'IR-O-U-0476.pdf',
#  'IR-O-U-0490.pdf',
#  'IR-O-U-0496.pdf',
#  'IR-O-U-0497.pdf',
#  'IR-O-U-0500.pdf',
#  'IR-O-U-0523.pdf',
#  'IR-O-U-0530.pdf',
#  'IR-O-U-0560.pdf',
#  'IR-O-U-0570.pdf',
#  'IR-O-U-0572.pdf',
#  'IR-O-U-0573.pdf',
#  'IR-O-U-0575.pdf',
#  'IR-O-U-0577.pdf',
#  'IR-O-U-0584.pdf',
#  'IR-O-U-0589.pdf',
#  'IR-O-U-0642.pdf',
#  'IR-O-U-0701.pdf',
#  'IR-O-U-0747.pdf']

# %%
## Dataframe containing placement data of all colleges
final = pd.DataFrame()
failed_colleges = [] #whose placement data has different shape than others

# %%
k = 0
for file in file_names:
    abc = camelot.read_pdf('2021/'+file, pages="all",flavor='lattice',line_scale=30) # file loation
    # line_space = 30 , this argument helps to read single row tables also. greater the value, higher the chances of detecting smaller tables.
    pdf_file = open('2021/'+file, 'rb')
    read_pdf = PyPDF2.PdfFileReader(pdf_file)
    number_of_pages = read_pdf.getNumPages()
    page = read_pdf.getPage(0)
    page_content = page.extractText()
    text=page_content.split(" ")
        
    name=''
    for i in range(15) :
        if text[16+i][0] == '[' :
            code=text[16+i].split(']')
            _,institute_code=code[0].split('[')
            #print(institute_code)
            break
        name=name+text[16+i]+' '
    print(name,k)
    k = k+1
    df = []
    i = 0
    while(i<len(abc)):
        df1 = abc[i].df
            
        if(i==len(abc)-1):
            df.append(df1)
            break
        df2 = abc[i+1].df
        # merging conditions for placement tables
        condition = df1.loc[df1.shape[0]-1][0]=='Academic Year'
        condition = condition | ((df1.loc[df1.shape[0]-1][0]=='2013-14') and (df2.loc[0][0]=='2014-15') )
        condition = condition | ((df1.loc[df1.shape[0]-1][0]=='2014-15') and (df2.loc[0][0]=='2015-16') )
        condition = condition | ((df1.loc[df1.shape[0]-1][0]=='2015-16') and (df2.loc[0][0]=='2016-17') )
        condition = condition | ((df1.loc[df1.shape[0]-1][0]=='2016-17') and (df2.loc[0][0]=='2017-18') )
        condition = condition | ((df1.loc[df1.shape[0]-1][0]=='2017-18') and (df2.loc[0][0]=='2018-19') )
        condition = condition | ((df1.loc[df1.shape[0]-1][0]=='2018-19') and (df2.loc[0][0]=='2019-20') )
        
        if (condition):
            x = pd.DataFrame(np.vstack((np.array(df1),np.array(df2))))

            df.append(x)
            i = i+2
        else:
            df.append(df1)
            i =i+1
    x = df[1].copy()
    x.columns = x.loc[0]
    x = x[1:]
    x
    p = []
    for i in range(x.shape[0]):
        programme = x.iloc[i]['(All programs\nof all years)']
        p.append(programme)

    for i in p:
        p_name = i
        j = 2
        y = df[j].copy()
        y.columns = y.loc[0]
        j = j+1
        y = y[1:]
        y['Program_name'] = p_name
        y['Institute'] = name
        try:
            final = final.append(y, ignore_index=True)
        except:
            failed_colleges.append(name+p_name)
# Out:
# Sri Sivasubramaniya Nadar College of Engineering  0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\CHABIL~1\AppData\Local\Temp/ipykernel_15672/4227825920.py in <module>
#       1 k = 0
#       2 for file in file_names:
# ----> 3     abc = camelot.read_pdf('2021/'+file, pages="all",flavor='lattice',line_scale=30) # file loation
#       4     # line_space = 30 , this argument helps to read single row tables also. greater the value, higher the chances of detecting smaller tables.
#       5     pdf_file = open('2021/'+file, 'rb')
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\camelot\io.py in read_pdf(filepath, pages, password, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     111         p = PDFHandler(filepath, pages=pages, password=password)
#     112         kwargs = remove_extra(kwargs, flavor=flavor)
# --> 113         tables = p.parse(
#     114             flavor=flavor,
#     115             suppress_stdout=suppress_stdout,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\camelot\handlers.py in parse(self, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     174             parser = Lattice(**kwargs) if flavor == "lattice" else Stream(**kwargs)
#     175             for p in pages:
# --> 176                 t = parser.extract_tables(
#     177                     p, suppress_stdout=suppress_stdout, layout_kwargs=layout_kwargs
#     178                 )
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\camelot\parsers\lattice.py in extract_tables(self, filename, suppress_stdout, layout_kwargs)
#     419             return []
#     420
# --> 421         self.backend.convert(self.filename, self.imagename)
#     422
#     423         self._generate_table_bbox()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\camelot\backends\ghostscript_backend.py in convert(self, pdf_path, png_path, resolution)
#      45             pdf_path,
#      46         ]
# ---> 47         ghostscript.Ghostscript(*gs_command)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\ghostscript\__init__.py in __init__(self, stdin, stdout, stderr, *args)
#      85         try:
#      86             self.set_stdio(stdin, stdout, stderr)
# ---> 87             rc = gs.init_with_args(self._instance, args)
#      88             if rc == gs.e_Info:
#      89                 raise PleaseDisplayUsage()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\ghostscript\_gsprint.py in init_with_args(instance, argv)
#     284     ArgArray = c_char_p * len(argv)
#     285     c_argv = ArgArray(*argv)
# --> 286     rc = libgs.gsapi_init_with_args(instance, len(argv), c_argv)
#     287     if rc not in (0, e_Quit, e_Info):
#     288         raise GhostscriptError(rc)
#
# KeyboardInterrupt:

# %%
final
# Out:
# 0    Academic Year No. of first year\nstudents intake in the\nyear  \
# 0          2014-15                                             819
# 1          2015-16                                             819
# 2          2016-17                                             780
# 3          2014-15                                             819
# 4          2015-16                                             819
# ...            ...                                             ...
# 1201       2016-17                                            1320
# 1202       2017-18                                            2140
# 1203       2015-16                                            1290
# 1204       2016-17                                            1320
# 1205       2017-18                                            2140
#
# 0    No. of first year\nstudents admitted in\nthe year Academic Year  \
# 0                                                  829       2015-16
# 1                                                  826       2016-17
# 2                                                  830       2017-18
# 3                                                  829       2015-16
# 4                                                  826       2016-17
# ...                                                ...           ...
# 1201                                              1302       2017-18
# 1202                                              2098       2018-19
# 1203                                              1273       2016-17
# 1204                                              1302       2017-18
# 1205                                              2098       2018-19
#
# 0    No. of students\nadmitted through\nLateral entry Academic Year  \
# 0                                                 101       2017-18
# 1                                                 101       2018-19
# 2                                                 101       2019-20
# 3                                                 101       2017-18
# 4                                                 101       2018-19
# ...                                               ...           ...
# 1201                                                0       2018-19
# 1202                                                0       2019-20
# 1203                                                0       2017-18
# 1204                                                0       2018-19
# 1205                                                0       2019-20
#
# 0    No. of students\ngraduating in\nminimum stipulated\ntime  \
# 0                                                   800
# 1                                                   787
# 2                                                   703
# 3                                                   800
# 4                                                   787
# ...                                                 ...
# 1201                                               1244
# 1202                                               1813
# 1203                                               1192
# 1204                                               1244
# 1205                                               1813
#
# 0    No. of students\nplaced  \
# 0                        633
# 1                        642
# 2                        579
# 3                        633
# 4                        642
# ...                      ...
# 1201                     798
# 1202                    1187
# 1203                     756
# 1204                     798
# 1205                    1187
#
# 0    Median salary of\nplaced\ngraduates(Amount in\nRs.)  \
# 0                                    400000(four lakhs)
# 1                    440000(four lakhs forty\nthousand)
# 2                                    500000(Five lakhs)
# 3                                    400000(four lakhs)
# 4                    440000(four lakhs forty\nthousand)
# ...                                                 ...
# 1201               218000(Two Lakh\nEighteen Thousand )
# 1202                   240000(Two Lakh\nForty Thousand)
# 1203                  180000(One Lakh\nEighty Thousand)
# 1204               218000(Two Lakh\nEighteen Thousand )
# 1205                   240000(Two Lakh\nForty Thousand)
#
# 0    No. of students\nselected for Higher\nStudies              Program_name  \
# 0                                              120  UG [4 Years\nProgram(s)]
# 1                                              123  UG [4 Years\nProgram(s)]
# 2                                              107  UG [4 Years\nProgram(s)]
# 3                                              120   PG [2 Year\nProgram(s)]
# 4                                              123   PG [2 Year\nProgram(s)]
# ...                                            ...                       ...
# 1201                                           446   PG [2 Year\nProgram(s)]
# 1202                                           626   PG [2 Year\nProgram(s)]
# 1203                                           436   PG [6 Year\nProgram(s)]
# 1204                                           446   PG [6 Year\nProgram(s)]
# 1205                                           626   PG [6 Year\nProgram(s)]
#
# 0                                             Institute
# 0     Sri Sivasubramaniya Nadar College of Engineering
# 1     Sri Sivasubramaniya Nadar College of Engineering
# 2     Sri Sivasubramaniya Nadar College of Engineering
# 3     Sri Sivasubramaniya Nadar College of Engineering
# 4     Sri Sivasubramaniya Nadar College of Engineering
# ...                                                 ...
# 1201                             Chandigarh University
# 1202                             Chandigarh University
# 1203                             Chandigarh University
# 1204                             Chandigarh University
# 1205                             Chandigarh University
#
# [1206 rows x 12 columns]

# %%
failed_colleges
# Out:
# ['University of Madras PG [2 Year\nProgram(s)]',
#  'University of Madras PG [3 Year\nProgram(s)]',
#  'University of Hyderabad PG [2 Year\nProgram(s)]',
#  'University of Hyderabad PG [3 Year\nProgram(s)]',
#  'University of Hyderabad PG-Integrated',
#  'Gujarat University PG [2 Year\nProgram(s)]',
#  'Kerala University PG [1 Year\nProgram(s)]',
#  'Kerala University PG [2 Year\nProgram(s)]',
#  'Homi Bhabha National Institute PG [1 Year\nProgram(s)]',
#  'Homi Bhabha National Institute PG [2 Year\nProgram(s)]',
#  'Homi Bhabha National Institute PG [3 Year\nProgram(s)]',
#  'Homi Bhabha National Institute PG-Integrated',
#  'Madurai Kamaraj University PG [1 Year\nProgram(s)]',
#  'Madurai Kamaraj University PG [2 Year\nProgram(s)]',
#  'Madurai Kamaraj University PG [3 Year\nProgram(s)]',
#  'Madurai Kamaraj University PG-Integrated']

# %%
final.to_csv('Outputs/placement2021.csv', index=False)

# %%
failed_colleges
# Out:
# ['University of Madras PG [2 Year\nProgram(s)]',
#  'University of Madras PG [3 Year\nProgram(s)]',
#  'University of Hyderabad PG [2 Year\nProgram(s)]',
#  'University of Hyderabad PG [3 Year\nProgram(s)]',
#  'University of Hyderabad PG-Integrated',
#  'Gujarat University PG [2 Year\nProgram(s)]',
#  'Kerala University PG [1 Year\nProgram(s)]',
#  'Kerala University PG [2 Year\nProgram(s)]',
#  'Homi Bhabha National Institute PG [1 Year\nProgram(s)]',
#  'Homi Bhabha National Institute PG [2 Year\nProgram(s)]',
#  'Homi Bhabha National Institute PG [3 Year\nProgram(s)]',
#  'Homi Bhabha National Institute PG-Integrated',
#  'Madurai Kamaraj University PG [1 Year\nProgram(s)]',
#  'Madurai Kamaraj University PG [2 Year\nProgram(s)]',
#  'Madurai Kamaraj University PG [3 Year\nProgram(s)]',
#  'Madurai Kamaraj University PG-Integrated']

# %% [markdown]
# # Managing failed colleges, whose dataframe has different shape

# %%
# Finding all file names in a folder
file_names = []
for i in os.listdir('2021/failed colleges'):
    # print(i)
    file_names.append(i)
file_names
# Out:
# ['IR-O-I-1357.pdf',
#  'IR-O-U-0042.pdf',
#  'IR-O-U-0136.pdf',
#  'IR-O-U-0260.pdf',
#  'IR-O-U-0304.pdf',
#  'IR-O-U-0463.pdf']

# %%
## Dataframe containing placement data of all colleges
final = pd.DataFrame()
failed_colleges = []

# %%
k = 0
for file in file_names:
    abc = camelot.read_pdf('2021/failed colleges/'+file, pages="all",flavor='lattice',line_scale=30) # file loation
    # line_space = 30 , this argument helps to read single row tables also. greater the value, higher the chances of detecting smaller tables.
    pdf_file = open('2021/failed colleges/'+file, 'rb')
    read_pdf = PyPDF2.PdfFileReader(pdf_file)
    number_of_pages = read_pdf.getNumPages()
    page = read_pdf.getPage(0)
    page_content = page.extractText()
    text=page_content.split(" ")
        
    name=''
    for i in range(15) :
        if text[16+i][0] == '[' :
            code=text[16+i].split(']')
            _,institute_code=code[0].split('[')
            #print(institute_code)
            break
        name=name+text[16+i]+' '
    print(name,k)
    k = k+1
    df = []
    i = 0
    while(i<len(abc)):
        df1 = abc[i].df
            
        if(i==len(abc)-1):
            df.append(df1)
            break
        df2 = abc[i+1].df
        # merging conditions for placement tables
        condition = df1.loc[df1.shape[0]-1][0]=='Academic Year'
        condition = condition | ((df1.loc[df1.shape[0]-1][0]=='2013-14') and (df2.loc[0][0]=='2014-15') )
        condition = condition | ((df1.loc[df1.shape[0]-1][0]=='2014-15') and (df2.loc[0][0]=='2015-16') )
        condition = condition | ((df1.loc[df1.shape[0]-1][0]=='2015-16') and (df2.loc[0][0]=='2016-17') )
        condition = condition | ((df1.loc[df1.shape[0]-1][0]=='2016-17') and (df2.loc[0][0]=='2017-18') )
        condition = condition | ((df1.loc[df1.shape[0]-1][0]=='2017-18') and (df2.loc[0][0]=='2018-19') )
        condition = condition | ((df1.loc[df1.shape[0]-1][0]=='2018-19') and (df2.loc[0][0]=='2019-20') )
        
        if (condition):
            x = pd.DataFrame(np.vstack((np.array(df1),np.array(df2))))

            df.append(x)
            i = i+2
        else:
            df.append(df1)
            i =i+1
    x = df[1].copy()
    x.columns = x.loc[0]
    x = x[1:]
    x
    p = []
    for i in range(x.shape[0]):
        programme = x.iloc[i]['(All programs\nof all years)']
        p.append(programme)

    for i in p:
        p_name = i
        j = 2
        y = df[j].copy()
        y.columns = y.loc[0]
        j = j+1
        y = y[1:]
        y['Program_name'] = p_name
        y['Institute'] = name
        try:
            final = final.append(y, ignore_index=True)
        except:
            failed_colleges.append(name+p_name)
# Out:
# University of Madras  0
# University of Hyderabad  1
# Gujarat University  2
# Kerala University  3
# Homi Bhabha National Institute  4
# Madurai Kamaraj University  5

# %%
final.to_csv('Outputs/placement2021_different_type_of_data.csv',index=False)
